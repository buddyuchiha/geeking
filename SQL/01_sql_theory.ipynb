# %% [markdown]
# __Базовая информация про SQL__
#
# БД - прога, которая умеет получать, доставать информацию исохранять на жестком диске
#
# СУБД (DBeaver, pgAdmin) - Система Управления Базами Данных или же набор инструментов, которые позволяют удобно управлять базами данных.
#
# Типы баз данных:
#
# 1) Простейшие
#
# Спсиок, Сеть, Иерархия
#
# 2) Реляционные SQL
#
# Организуют данные в одну или несколько таблиц
#
# Таблица — это самая распространенная и простая форма хранения данных в РБД. Каждая таблица состоит из небольших частей — полей (fields). Столбец/Поле - атрибут данных
#
# 3) NoSQL
#
# Предлагают отличные от таблиц подоходы (ключ-значение, графовая и так далее)
#
# SQL - язык программирования, предназначенный для работы с СУБД.
#
# Примеры SQL СУБД: PostgreSQL, MySQL, MSSQL
#
# При выполнении любой SQL-команды в любой RDBMS (Relational Database Management System — система управления РБД, СУБД, например, PostgreSQL, MySQL, MSSQL, SQLite и др.) система определяет наилучший способ выполнения запроса, а движок SQL определяет способ интерпретации задачи.
#
# В данном процессе участвует несколького компонентов:
#
# 1) Диспетчер запросов
#
# 2) Движок оптимизации
#
# 3) Классический движок запросов
#
# 4) Движок запросов SQL и т.д
#
# Классический движок обрабатывает все не-SQL-запросы, а движок SQL-запросов не обрабатывает логические файлы.
#
# PRIMARY KEY - уникальный идентификатор
#
# FOREIGN KEY - связь между таблицами

# %% [markdown]
# __Команды SQL__
#
# 1) DDL - язык определения данных
#
# ![image.png](attachment:image.png)
#
# 2) DML - язык изменения данных
#
# ![image-2.png](attachment:image-2.png)
#
# 3) DCL - язык управления данными
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# __Типы данных__
#
# 1) Точные числовые
#
# ![image.png](attachment:image.png)
#
# 2) Приблизительно числовые
#
# ![image-4.png](attachment:image-4.png)
#
# 3) Дата и время
#
# ![image-3.png](attachment:image-3.png)
#
# 4) Строковые символьные
#
# ![image-2.png](attachment:image-2.png)
#
# 5) Строки символьные (юникод)
#
# ![image-5.png](attachment:image-5.png)
#
# 6) Бинарные
#
# ![image-6.png](attachment:image-6.png)
#
# 7) Смешанные
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# __Порядок выполнения SQL - запросов__
#
# +![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Порядок важен для:
#
# Алиасов - можно использовать в ORDER BY, но не в WHERE/GROUP BY/HAVING
#
# Производительности - ранняя фильтрация (WHERE) уменьшает объем данных
#
# Логики - неправильный порядок может изменить результат
#
# Частые ошибки:
#
# 1) Использование алиасов не по порядку:
#
# ![image-3.png](attachment:image-3.png)
#
# 2) Путаница WHERE и HAVING
#
# ![image-4.png](attachment:image-4.png)
#
# 3) Порядок JOIN условий
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# __Операторы__ -  это ключевое слово или символ, которые, в основном, используются в инструкциях WHERE для выполнения каких-либо операций. Они используются как для определения условий, так и для объединения нескольких условий в инструкции.
#
# 1) Арифмитические
#
# ![image.png](attachment:image.png)
#
# 2) Операторы сравнения
#
# ![image-2.png](attachment:image-2.png)
#
# 3) Логические операторы
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# __Выражения__ - это комбинация значений, операторов и функций для оценки (вычисления) значения.
#
# 1) Логические
#
# ![image.png](attachment:image.png)
#
# 2) Числовые
#
# ![image-2.png](attachment:image-2.png)
#
# В числовых испольюзуются агрегирующие встроенные функции, такие как:
#
# ![image-3.png](attachment:image-3.png)
#
# Работа со строками:
#
# ![image-4.png](attachment:image-4.png)
#
# С числами:
#
# ![image-5.png](attachment:image-5.png)
#
# 3) Выражения для работы с датами
#
# ![image-6.png](attachment:image-6.png)
#
# Другие функции:
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)

# %% [markdown]
# __Предложения ORDER BY и GROUP BY__
#
# Предложение ORDER BY используется для сортировки данных по возрастанию (ASC) или убыванию (DESC). Многие СУБД по умолчанию выполняют сортировку по возрастанию.
#
# ![image.png](attachment:image.png)
#
# Предложение GROUP BY используется совместно с инструкцией SELECT для группировки записей. Оно указывается после WHERE и перед ORDER BY.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# __Связи между таблицами__
#
# 1. Один-к-одному (One-to-One)
#
# Одной записи в таблице A соответствует не более одной записи в таблице B
#
# Users ↔ UserProfiles (дополнительная информация о пользователе)
#
# ![image.png](attachment:image.png)
#
# 2. Один-ко-многим (One-to-Many)
#
# Одной записи в таблице A соответствует много записей в таблице B
#
# Department → Employees (в одном отделе много сотрудников)
#
# ![image-2.png](attachment:image-2.png)
#
# 3. Многие-ко-многим (Many-to-Many)
#
# Многим записям в таблице A соответствует много записей в таблице B
#
# Students ↔ Courses (студенты могут записаться на много курсов, на курс может записаться много студентов)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# __Остальное__
#
# _Ключевое слово DISTINCT_
#
# Ключевое слово DISTINCT используется совместно с инструкцией SELECT для возврата только уникальных записей (без дубликатов).
#
# ![image-3.png](attachment:image-3.png)
#
# _Предложения LIKE и REGEX_
#
# LIKE используется для сравнения значений с помощью операторов с подстановочными знаками. Существует два вида таких операторов:
#
# 1) проценты %
#
# 0, 1 или более символов
#
# 2) нижнее подчериквание _
#
# только 1 символ
#
# ![image-2.png](attachment:image-2.png)
#
# _Ограничения_ - это правила, применяемые к данным. Они используются для ограничения данных, которые могут быть записаны в таблицу. Это обеспечивает точность и достоверность данных в БД.
#
# ![image.png](attachment:image.png)
#
# _Синонимы_
#
# Позволяют временно изменять названия таблиц и колонок. "Временно" означает, что новое название используется только в текущем запросе, в БД название остается прежним.
#
# ![image-4.png](attachment:image-4.png)
#
# _Индексы_
#
# Индексы — это специальные поисковые таблицы (lookup tables), которые используются движком БД в целях более быстрого извлечения данных. Проще говоря, индекс — это указатель или ссылка на данные в таблице.
#
#
# Индексы ускоряют работу инструкции SELECT и предложения WHERE, но замедляют работу инструкций UPDATE и INSERT. Индексы могут создаваться и удаляться, не оказывая никакого влияния на данные.
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# индексы не должны использоваться в маленьких таблицах
#
# _Обновление таблицы_
#
# Команда ALTER TABLE используется для добавления, удаления и модификации колонок существующей таблицы. Также эта команда используется для добавления и удаления ограничений.
#
# ![image-8.png](attachment:image-8.png)
#
# _Нормализация_ это процесс эффективной организации данных в БД. Существует две главных причины, обуславливающих необходимость нормализации:
#
# 1) предотвращение записи в БД лишних данных, например, хранения одинаковых данных в разных таблицах
#
# 2) обеспечение "оправданной" связи между данными
