# %% [markdown]
# __Небольшая справка о SQLite__

# %% [markdown]
# Просто пример подключения:
#
# ![image.png](attachment:image.png)
#
# Для взаимодействия с базой данных, нам необходимо создать объект курсор:
#
# ![image-2.png](attachment:image-2.png)
#
# Ну и используя его мы передаем SQL-запросы
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Такая конструкция намного удобнее и безопаснее, так как она сама закрывает доступ к БД
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Типы данных SQLite:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Пример создания таблицы:
#
# ![image.png](attachment:image.png)
#
# Удаление таблицы:
#
# ![image-2.png](attachment:image-2.png)
#
# Для вставки и выделения данных мы используем:
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# Пример:
#
# ![image-3.png](attachment:image-3.png)
#
# OFFSET -> означает пропустить первые 2 записи

# %% [markdown]
# Чтобы получить результат, используем метод fetchall()
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# Ну или выводить все последовательно
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Для изменения и удаление записей:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Пример:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Пример:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# __Группировка__
#
# ![image.png](attachment:image.png)
#
# Она позволит нам выполнять агрегирующие функции для каких-либо групп
#
# ![image-2.png](attachment:image-2.png)
#
# Пример:
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Для объединения данных используется JOIN
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Таблицы также можно объединять:
#
# ![image.png](attachment:image.png)
