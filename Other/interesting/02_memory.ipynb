# %% [markdown]
# __Python Memory Management на пальцах__

# %% [markdown]
# В CPython все данные хранятся в куче.
#
# В стэке хранятся ссылки на эти данные.
#
# ![image.png](attachment:image.png)
#
# При
#
# ![image-3.png](attachment:image-3.png)
#
# Списки будут равны, но храниться они будут в разных ячейках памяти
#
# В изменяемый элемент кортежа (например список), можно что-либо добавить:
#
# ![image-2.png](attachment:image-2.png)
#
# Суть в том, что кортеж хранит ссылку на объект в памяти этого списка, то есть сама ссылка никак не поменяется.
#
# Сборщик мусора в пайтон занимается очисткой той оперативной памяти, которая нам не нужна.
#
# Он работает в двух режимах:
#
# 1) Подсчет ссылок
#
# У нас есть тип данные в куче, на которые ссылаются переменные, когда количество ссылок = 0, эти данные удаляются
#
# 2) Трейсинг
#
# Он эффективно очищает циклично ссылающиеся друг на друга данные

# %% [markdown]
# __ОООООЧЕНЬ ПРОСТОЙ ПРИМЕР ВНИЗУ__

# %% [markdown]
# При a = [1, 2, 3]
#
# a _указывает_ на [1, 2, 3]
#
# сама переменная эт указатель
#
# ![image.png](attachment:image.png)
#
# при объявлении
#
# b = a
#
# b начинает также _указывать_ на [1, 2, 3]
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Чтоб получить количество ссылок указывающих на переменную:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Если питон видит, что на объект 0 ссылок -> он его удаляет.

# %% [markdown]
# del удаляет ссылку на объект, а не переменную
