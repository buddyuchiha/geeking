# %% [markdown]
# __Jinja__

# %% [markdown]
# Служит для обработки шаблонов в Python.
#
# Основан на блоках {%...%} для логики, выражений {{}} для вывода переменных и комментариев {#...#}
#
# Чтоб установить:
#
# pip install jinja2
#
# Минимальный пример:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# _Основы синтаксиса Jinja2_
#
# Вывод переменных:
#
# ![image.png](attachment:image.png)
#
# Условия:
#
# ![image-2.png](attachment:image-2.png)
#
# Циклы:
#
# ![image-3.png](attachment:image-3.png)
#
# Наследование шаблонов:
#
# 1) Создаем файл с каркасом сайта и блоками, которые будут заменяться
#
# ![image-4.png](attachment:image-4.png)
#
# 2) Создаем дочерний шаблон
#
# ![image-5.png](attachment:image-5.png)
#
# Подключение статических файлов:
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# Формы и обработка данных:
#
# 1) Создадим шаблон формы form.html
#
# ![image-8.png](attachment:image-8.png)
#
# 2) Обработаем ее в FastAPI
#
# ![image-9.png](attachment:image-9.png)
