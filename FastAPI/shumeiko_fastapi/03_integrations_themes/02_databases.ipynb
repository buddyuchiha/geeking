# %% [markdown]
# __Базы данных в FastAPI__

# %% [markdown]
# Для примера работы скачаем aiosqlite, sqlalchemy, fastapi и из новых:
#
# ![image-12.png](attachment:image-12.png) <- для асинхронки sqlalchemy
#
# Импортируем асинхронный движок и асинхронную сессию
#
# ![image.png](attachment:image.png)
#
# Создаем движок
#
# ![image-2.png](attachment:image-2.png)
#
# Создание новой сессии
#
# ![image-3.png](attachment:image-3.png)
#
# Создадим генератор session
#
# ![image-4.png](attachment:image-4.png)
#
# Созадим базовый класс
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# Создадим класс для книг
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-7.png](attachment:image-7.png)
#
# Создадим генератора database
#
# ![image-10.png](attachment:image-10.png)
#
# В metadata хранятся все данные о всех таблицах
#
# Создаем экземпляр класса фастапи и делаем ручку для setup
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-13.png](attachment:image-13.png)
#
# Запускаем фастапи и тестим ручку
#
# ![image-11.png](attachment:image-11.png)
#
# ![image-14.png](attachment:image-14.png)
#
# ![image-15.png](attachment:image-15.png)

# %% [markdown]
# Напишем ручки с использованием Pydantic:
#
# 1) Напишем схемы Pydantic
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# 2) Чтоб получать сессию используем зависимость Depends
#
# ![image-3.png](attachment:image-3.png)
#
# импортируем Annotated из typing и AsyncSeesion из
#
# ![image-4.png](attachment:image-4.png)
#
# создаем зависимость
#
# ![image-5.png](attachment:image-5.png)
#
# 3) POST - запрос
#
# ![image-7.png](attachment:image-7.png)
#
# 4) GET - запрос
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-11.png](attachment:image-11.png)
