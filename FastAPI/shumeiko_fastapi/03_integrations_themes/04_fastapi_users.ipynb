# %% [markdown]
# __FastAPI Users__

# %% [markdown]
# FastAPI Users - готовое решение для аутентификации и управления пользователями в FastAPI приложениях.
#
# Способы аутентификации:
#
# * JWT - JSON Web tokens
# * Cookie - сессии через куки
# * OAuth - вход через соцсети
#
# Установка:
#
# ![image-2.png](attachment:image-2.png)
#
# Конфигурация аутентификации:
#
# ![image.png](attachment:image.png)
#
# Примеры эндпоинтов:
#
# ![image-3.png](attachment:image-3.png)
#
# Простая проверка аутентификации:
#
# ![image-4.png](attachment:image-4.png)
#
# Другие параметры:
#
# ![image-5.png](attachment:image-5.png)
#
# Как все работает (супер-упрощенно)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
