# %% [markdown]
# __Роутеры__

# %% [markdown]
# Роутеры (маршрутизаторы) в FastAPI - способ организации кода приложения путем группировки связанных эндпоинтов.
#
# Они позволяют разбивать большое приложение на модули, что улучшает поддерживаемость и читаемость кода.

# %% [markdown]
# _Пример создания роутера_
#
# ![image.png](attachment:image.png)
#
# Все параметры конструктора APIRouter:
#
# ![image-2.png](attachment:image-2.png)
#
# Регистрация ротуера:
#
# ![image-3.png](attachment:image-3.png)
#
# Ротуеры часто используют с зависимостями
#
# Зависимости - функции или классы, которые выполняются перед обработкой запроса.
#
# Примеры роутеров с зависимостями:
#
# ![image-4.png](attachment:image-4.png)
#
# Вложенные роутеры:
#
# ![image-5.png](attachment:image-5.png)
#
# Роутеры советуют хорошо документировать:
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# Реальные кейсы применения:
#
# 1) Многоуровневая архитектура приложения
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# 2) Версионирование API
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# 3) Микросервисная архитектура
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
