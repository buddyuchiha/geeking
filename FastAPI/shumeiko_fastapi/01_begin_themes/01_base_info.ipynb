# %% [markdown]
# __Базовая информация__

# %% [markdown]
# FastAPI - Фреймворк для разработки API
#
# Чтоб начать работу с фастапи:
#
# 1) Созадем и активируем виртуальное окружение
#
# ![image.png](attachment:image.png)
#
# 2) Устанавливаем библиотеку
#
# Можно так:
#
# ![image-2.png](attachment:image-2.png)
#
# Но в качестве примера установят так:
#
# ![image-3.png](attachment:image-3.png)
#
# 3) В main.py импортируем класс
#
# ![image-4.png](attachment:image-4.png)
#
# 4) Создаем экземпляр класса:
#
# ![image-5.png](attachment:image-5.png)
#
# Создание базового GET-запроса:
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# Первый способ запуска FastAPI:
#
# ![image.png](attachment:image.png)
#
# На сайте с документацией мы увидим наши хэндлеры:
#
# ![image-2.png](attachment:image-2.png)
#
# Так можно более понятно расписать про хэндеры:
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# FastAPI не умеет самостоятельно принимать запросы от клиента, это делает за него веб-сервер
#
# Веб-сервер называется uvicorn
#
# Второй способ запуска FastAPI:
#
# ![image-5.png](attachment:image-5.png)
#
# Третий способ запуска FastAPI:
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# Кратко как чо работает:
#
# ![image.png](attachment:image.png)
#
# Пользователь зайдет на сайт (есть фронтенд), этот браузер посылает запрос в веб-сервер под названием NGINX, NGINX передает запрос uvicorn, а uvicron принимает запрос и отдает его FastAPI приложению, затем FastAPI передает запрос в наше приложение и там уже происходит какая-либо бизнес логика
