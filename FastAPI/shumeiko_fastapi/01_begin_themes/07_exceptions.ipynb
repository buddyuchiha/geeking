# %% [markdown]
# __Обработка ошибок FastAPI__

# %% [markdown]
# FastAPI предоставляет несколько уровней обработки ошибок:
#
# 1. Встроенные исключения
# 2. HTTPException
#
# ![image.png](attachment:image.png)
#
# 3. Пользовательские обработчики
#
# ![image-2.png](attachment:image-2.png)
#
# 4. Middleware обработки
#
# Пример базовой обработки ошибок:
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# Пример пользовательских обработчиков и исключений:
#
# ![image-5.png](attachment:image-5.png)
