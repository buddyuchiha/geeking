# %% [markdown]
# __Как запустить FastAPI в Docker контейнере__

# %% [markdown]
# main.py
#
# ![image.png](attachment:image.png)
#
# Создание Dockerfile
#
# В нем будут инструкции, как собирается и запускается наше приложение
#
# Для начала нам нужен образ python 3.12 или python 3.13
#
# ![image-5.png](attachment:image-5.png)
#
# Как создать образ?
#
# ![image-4.png](attachment:image-4.png)\
#
# Посмотреть этот образ
#
# ![image-2.png](attachment:image-2.png)
#
# Запустить контейнер
#
# ![image-3.png](attachment:image-3.png)
#
# Сразу мы не можем перейти на сайт, так как мы не прокинули порты
#
# Докер запускается в своей докер-сети и мы не можем к ней сразу достучаться, нам нужно проложить путь
#
# указываем через -p
#
# ![image-6.png](attachment:image-6.png)
#
# Все работает:
#
# ![image-7.png](attachment:image-7.png)
#
# Папку app мы создаем, чтобы сразу отдалить наше приложение от остальных папок с файлами
