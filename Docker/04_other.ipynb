# %% [markdown]
# __Доп. информация__

# %% [markdown]
# Если докер применяется для управления отдельными контейнерами, то Docker Compose используется для одновременного управления несколькими контейнерами, все описывается в yml
#
# нужно описать каждый сервис
#
# ![image.png](attachment:image.png)
#
# database:
# - определим уже готовый образ
# - переменные, которые мы задаем (пароль, юзернейм, дбнейм)
# - проверим хелсчек, определяем работоспосбность сервера
# - тома данных (volumes)
#
# ![image-2.png](attachment:image-2.png)
#
# search определяется аналогично:
#
# ![image-3.png](attachment:image-3.png)
#
# backend:
#
# - впишем название образа
# - собираем образ, указывая путь к докерфайлу
# - зависимость, что db и search доступны
# - определим переменные окружения
#
# ![image-4.png](attachment:image-4.png)
#
# frontend:
#
# - описываем образ
# - открываем порты приложения
# - определяем перенные
# - указываем зависимости
#
# ![image-5.png](attachment:image-5.png)
#
# Теперь построим все:
#
# ![image-6.png](attachment:image-6.png)
#
# build нужен, чтобы построить образы для бэка и фронта
#
# Список сервисов:
#
# ![image-7.png](attachment:image-7.png)
#
# Оффаем сервисы:
#
# ![image-8.png](attachment:image-8.png)
