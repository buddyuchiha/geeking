# %% [markdown]
# __Модуль requests__

# %% [markdown]
# Библиотека помогает работать с http
#
# Чтобы взять какой-либо веб-ресурс мы используем GET:
#
# ![image.png](attachment:image.png)
#
# В ответе получаем статус-код:
#
# ![image-2.png](attachment:image-2.png)
#
# 200 означает, что все нормалек
#
# Для быстрой проверки можно использовать response.ok
#
# 404 означает, что веб-ресурс не найден
#
# 500 означает, что ошибка на сервере
#
# Чтобы возвращать именно integer, мы используем:
#
# ![image-3.png](attachment:image-3.png)
#
# Мы можем испльзовать .content, чтобы вернуть HTML-код страницы в виде бинарной строки:
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# Но легче использовать .text
#
# Клиент и сервер общаются только с помощью байт
#
# Так можно передавать параметры в запрос:
#
# ![image-6.png](attachment:image-6.png)
#
# .headers - метаинформация (загловки), которые идут с ответом сервера
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# POST и PUT позволяют создавать и обновлять данные
#
# Для передачи данных при создании используется атрибут data:
#
# ![image-9.png](attachment:image-9.png)
#
# Или атрибут json, который нужен для того, чтоб объект переделался в JSON при передаче:
#
# ![image-10.png](attachment:image-10.png)
#
# .reason позволяет посмотреть что именно не так с запросом
#
# чтоб запросы передавались на сайт и не блокировались как бот, необходимо определить заголовки и передать их в GET-запрос через атрибует headers:
#
# ![image-12.png](attachment:image-12.png)
#
# Ну и небольшой пример POST - запроса:
#
# ![image-11.png](attachment:image-11.png)
#
# Для поддержания состояния между запросами можно использовать Сессии:
#
# ![image-13.png](attachment:image-13.png)
#
# А так можно парсить фотки:
#
# ![image-14.png](attachment:image-14.png)
#
# Пример обработки исключений:
#
# ![image-15.png](attachment:image-15.png)
