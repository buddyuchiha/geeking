# %% [markdown]
# __Работа с алембик__

# %% [markdown]
# Создать алембик:
#
# ![image.png](attachment:image.png)
#
# Появился файлик alembic.ini в корне проекта:
#
# ![image-2.png](attachment:image-2.png)
#
# И директория для версий:
#
# ![image-3.png](attachment:image-3.png)
#
# В env.py мы будем конфигурировать какие модели у нас есть, какая у нас бд, подключение адрес и т.д
#
# так можно поменять путь до бд, определив метод config.set_main_option():
#
# ![image-4.png](attachment:image-4.png)
#
# Если асинхронный варик, то:
#
# ![|](attachment:image-9.png)
#
# в target_metadata передаются все созданные нами таблицы (модели данных)
#
# мы используем уже наш созданный Base класс с метаинфой:
#
# ![image-5.png](attachment:image-5.png)
#
# и импортируем его в env.py, присваивая значение target_metadata
#
# 1) ![image-6.png](attachment:image-6.png)
#
# 2) ![image-7.png](attachment:image-7.png)
#
# !! ОБЯЗАТЕЛЬНО ДОПОЛНИТЕЛЬНО НУЖНО ИМПОРТИРОВАТЬ ВСЕ ФАЙЛЫ С МОДЕЛЯМИ
#
# ![image-8.png](attachment:image-8.png)
#
# Чтоб сделать первую миграцию:
#
# ![image-10.png](attachment:image-10.png)
#
# Увидим файлик в папке versions и увидим функции upgrade() и downgrade()
#
# ![image-11.png](attachment:image-11.png)
#
# Команда, чтоб накатить все миграции, которые есть:
#
# ![image-12.png](attachment:image-12.png)
#
# Если мы хотим докатиться только до определенной миграции, то мы указываем ее номер
#
# Чуть-чуть поменяем код и увидим новые функции:
#
# ![image-13.png](attachment:image-13.png)
#
# важно установить compare_server_default:
#
# ![image-14.png](attachment:image-14.png)
#
# Алембик фиксанет чиста исправления
#
# Как откатиться назад:
#
# ![image-15.png](attachment:image-15.png)
#
# Чтоб откатить все миграции:
#
# ![image-16.png](attachment:image-16.png)
#
# _Форматирование файлов миграций_
#
# В файле alembic.ini можно задать форматироващика, просто расскоментить эт:
#
# ![image-17.png](attachment:image-17.png)
#
# и установить библиотеку black:
#
# ![image-18.png](attachment:image-18.png)
#
# Получим форматирование:
#
# ![image-19.png](attachment:image-19.png)
#
# ![image-20.png](attachment:image-20.png)
