# %% [markdown]
# __Как конвертировать SQLAlchemy в Pydantic и FastAPI__

# %% [markdown]
# Пример хорошй вложенной структуры:
#
# ![image.png](attachment:image.png)
#
# DTO (Data Transfer Object) - класс, который передает данные между различными сервисами приложения
#
# ![image-2.png](attachment:image-2.png)
#
# Если мы работаем с API, то рекомендуется сначала сделать DTO для POST-запроса, а потом уже наследоваться и делать DTO для GET
#
# Pydantic облегчает конвертацию в удобную форму, вот пример:
#
# ![image-3.png](attachment:image-3.png)
#
# Также с relationship:
#
# ![image-4.png](attachment:image-4.png)
